# %% [markdown]
# ## Slab Morphology
# The endothermic phase change at 660 km may impede the slab sinking through from the upper mantle into the lower mantle, affecting the slab's structure as it interacts with the mantle transition zone (MTZ).
#
# The most detailed information we have of slab structure comes from seismic tomography (see figure below). Several factors influence the slab morphology including its strength, age, trench motion (advance or rollback), viscosity jump at the MTZ, and Clapeyron slope of the phase transition.
#
#
# <img src='./images/slab_morphology.png' width="800" align="center"/>
#
# Summary of slab morphologies as imaged by the tomographic studies and their stress states: extensional (black) and compressional (white), inferred from the focal mechanisms of earthquakes occuring within the subducting slabs. Horizontal black line represents the base of the transition zone. Image: Goes et al. (2017)

# %% [markdown]
# ### Trench motion
# Slab morphology at the MTZ also affects the surface trench rollback/advance motions. Integrated over the last 50 Ma, most flattened slabs have undergone trench retreat (see figure below).
#
#
# <img src='./images/trench_rollback.png' width="500" align="center"/>
#
# Estimates of trench retreat over the last ~ 50 Ma compared with estimates of flat slab length. Image: Goes et al. (2017)
#
# Subduction dynamics that govern the trench motion can be understood using numerical models.

# %% [markdown]
# ### Dynamic models of subducting slab
#
# #### Influence of slab age
# Dynamic models show that older slabs are denser and more resistant to bending, which lead to stronger trench retreat than the younger slabs.
#
# Moreover, models by Garel et al. (2014) suggest that older overriding plates inhibit trench retreat as they offer more resistance to stretching induced from the slab pull and associated corner flow generated in the mantle wedge.
#
#
# <img src='./images/slab_folding.png' width="800" align="center"/>
#
# Various deformation modes of the subducting slab at the MTZ. Image: Goes et al. (2017), models by Garel et al. (2014)

# %% [markdown]
# #### Influence of 660 km phase change
#
# Agrusta et al. (2017) characterize slab's dynamics for varying Clapeyron slope and viscosity jump values at the 660 km boundary (see figure below).
#
# At high Clapeyron slopes, slabs of all ages are likely to stagnate while at low Clapeyron slope values, slabs of all ages are likely to penetrate if the viscosity jump to lower mantle is not too high.
# Increasing the viscosity of lower mantle, causes some older slabs to stagnate even at low Clapeyron values.
#
#
# <img src='./images/slab_dynamics.png' width="800" align="center"/>
#
# Regime diagram showing where old and young slabs either both penetrate ("dominant penetration") or both stagnate ("dominant stagnation") or old ones stagnate while young ones penetrate ("both models"). Image: Goes et al. (2017), models by Agrusta et al. (2017)

# %% [markdown]
# ##### References
# - Garel, F., Goes, S., Davies, D. R., Davies, J. H., Kramer, S. C., & Wilson, C. R. (2014). Interaction of subducted slabs with the mantle transition‐zone: A regime diagram from 2‐D thermo‐mechanical models with a mobile trench and an overriding plate. Geochemistry, Geophysics, Geosystems, 15(5), [1739-1765](https://agupubs.onlinelibrary.wiley.com/doi/full/10.1002/2014GC005257).
#
# - Agrusta, R., Goes, S., & Van Hunen, J. (2017). Subducting-slab transition-zone interaction: Stagnation, penetration and mode switches. Earth and Planetary Science Letters, [464, 10-23](https://www.sciencedirect.com/science/article/pii/S0012821X17300651).
# (
# - Goes, S., Agrusta, R., van Hunen, J., & Garel, F. (2017). Subduction-transition zone interaction: A review. Geosphere, 13(3), [644-664](https://pubs.geoscienceworld.org/gsa/geosphere/article/13/3/644/208074/Subduction-transition-zone-interaction-A-review).

# %% [markdown]
#  &nbsp;<div style="text-align: right">
#     &rarr; <b>NEXT: [ASPECT.prm file description](./4_prm_file_description.ipynb) </b> <a href=""></a> &nbsp;&nbsp;
#      <img src="../../../assets/education-gem-notebooks_icon.png" alt="icon"  width="4%">
#   </div>
